# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#reading csv file
df=pd.read_csv('covid_19_data.csv')
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# ...

# %%
df.shape
# Out:
# (306429, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  object
#  2   Province/State   228329 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  object
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 18.7+ MB

# %%
#checking any null values
df.isnull().sum()
# Out:
# SNo                    0
# ObservationDate        0
# Province/State     78100
# Country/Region         0
# Last Update            0
# Confirmed              0
# Deaths                 0
# Recovered              0
# dtype: int64

# %%
#describing the data
df.describe()
# Out:
#                  SNo     Confirmed         Deaths     Recovered
# count  306429.000000  3.064290e+05  306429.000000  3.064290e+05
# mean   153215.000000  8.567091e+04    2036.403268  5.042029e+04
# std     88458.577156  2.775516e+05    6410.938048  2.015124e+05
# min         1.000000 -3.028440e+05    -178.000000 -8.544050e+05
# 25%     76608.000000  1.042000e+03      13.000000  1.100000e+01
# 50%    153215.000000  1.037500e+04     192.000000  1.751000e+03
# 75%    229822.000000  5.075200e+04    1322.000000  2.027000e+04
# max    306429.000000  5.863138e+06  112385.000000  6.399531e+06

# %%
#checking null values
df.nunique()
# Out:
# SNo                306429
# ObservationDate       494
# Province/State        737
# Country/Region        229
# Last Update          1905
# Confirmed          107146
# Deaths              20089
# Recovered           74541
# dtype: int64

# %%
df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
df.tail()
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 306424  2021-05-30 04:20:55   102641.0  2335.0    95289.0
# 306425  2021-05-30 04:20:55    29147.0   245.0        0.0
# 306426  2021-05-30 04:20:55     1364.0     1.0     1324.0
# 306427  2021-05-30 04:20:55    87550.0  1738.0    83790.0
# 306428  2021-05-30 04:20:55   391559.0  4252.0        0.0

# %%
# cleaning the Data by renaming the columnn names
df=df.rename(columns={'Province/State':'State',
                     'Country/Region':'Country',
                     'ObservationDate':'Date'})
df
# Out:
#            SNo        Date              State         Country  \
# 0            1  01/22/2020              Anhui  Mainland China
# 1            2  01/22/2020            Beijing  Mainland China
# 2            3  01/22/2020          Chongqing  Mainland China
# 3            4  01/22/2020             Fujian  Mainland China
# 4            5  01/22/2020              Gansu  Mainland China
# ...        ...         ...                ...             ...
# 306424  306425  05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426  05/29/2021            Zeeland     Netherlands
# 306426  306427  05/29/2021           Zhejiang  Mainland China
# 306427  306428  05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429  05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# 1           1/22/2020 17:00       14.0     0.0        0.0
# ...

# %%
#changing the country and date time format
df.loc[df['Country']=='Mainland China','Country']='China'
df['Date'] = pd.to_datetime(df['Date'],format='%m/%d/%Y')
df['Day'] = df.Date.dt.dayofyear

# %%
df
# Out:
#            SNo       Date              State      Country  \
# 0            1 2020-01-22              Anhui        China
# 1            2 2020-01-22            Beijing        China
# 2            3 2020-01-22          Chongqing        China
# 3            4 2020-01-22             Fujian        China
# 4            5 2020-01-22              Gansu        China
# ...        ...        ...                ...          ...
# 306424  306425 2021-05-29  Zaporizhia Oblast      Ukraine
# 306425  306426 2021-05-29            Zeeland  Netherlands
# 306426  306427 2021-05-29           Zhejiang        China
# 306427  306428 2021-05-29    Zhytomyr Oblast      Ukraine
# 306428  306429 2021-05-29       Zuid-Holland  Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered  Day
# 0           1/22/2020 17:00        1.0     0.0        0.0   22
# 1           1/22/2020 17:00       14.0     0.0        0.0   22
# 2           1/22/2020 17:00        6.0     0.0        0.0   22
# ...

# %%
#filling the null values
df['State'].fillna(method='ffill',inplace=True)

# %%
df.isnull().sum()
# Out:
# SNo            0
# Date           0
# State          0
# Country        0
# Last Update    0
# Confirmed      0
# Deaths         0
# Recovered      0
# Day            0
# dtype: int64

# %%
df.isnull().any()
# Out:
# SNo            False
# Date           False
# State          False
# Country        False
# Last Update    False
# Confirmed      False
# Deaths         False
# Recovered      False
# Day            False
# dtype: bool

# %%
#checking the last update
df['Last Update']=pd.to_datetime(df['Last Update'])
df
# Out:
#            SNo       Date              State      Country         Last Update  \
# 0            1 2020-01-22              Anhui        China 2020-01-22 17:00:00
# 1            2 2020-01-22            Beijing        China 2020-01-22 17:00:00
# 2            3 2020-01-22          Chongqing        China 2020-01-22 17:00:00
# 3            4 2020-01-22             Fujian        China 2020-01-22 17:00:00
# 4            5 2020-01-22              Gansu        China 2020-01-22 17:00:00
# ...        ...        ...                ...          ...                 ...
# 306424  306425 2021-05-29  Zaporizhia Oblast      Ukraine 2021-05-30 04:20:55
# 306425  306426 2021-05-29            Zeeland  Netherlands 2021-05-30 04:20:55
# 306426  306427 2021-05-29           Zhejiang        China 2021-05-30 04:20:55
# 306427  306428 2021-05-29    Zhytomyr Oblast      Ukraine 2021-05-30 04:20:55
# 306428  306429 2021-05-29       Zuid-Holland  Netherlands 2021-05-30 04:20:55
#
# ...

# %%
# changing values float to int

# %%
df['Confirmed'] = df['Confirmed'].astype('int64')
df['Deaths'] = df['Deaths'].astype('int64')
df['Recovered'] = df['Recovered'].astype('int64')
df
# Out:
#            SNo       Date              State      Country         Last Update  \
# 0            1 2020-01-22              Anhui        China 2020-01-22 17:00:00
# 1            2 2020-01-22            Beijing        China 2020-01-22 17:00:00
# 2            3 2020-01-22          Chongqing        China 2020-01-22 17:00:00
# 3            4 2020-01-22             Fujian        China 2020-01-22 17:00:00
# 4            5 2020-01-22              Gansu        China 2020-01-22 17:00:00
# ...        ...        ...                ...          ...                 ...
# 306424  306425 2021-05-29  Zaporizhia Oblast      Ukraine 2021-05-30 04:20:55
# 306425  306426 2021-05-29            Zeeland  Netherlands 2021-05-30 04:20:55
# 306426  306427 2021-05-29           Zhejiang        China 2021-05-30 04:20:55
# 306427  306428 2021-05-29    Zhytomyr Oblast      Ukraine 2021-05-30 04:20:55
# 306428  306429 2021-05-29       Zuid-Holland  Netherlands 2021-05-30 04:20:55
#
# ...

# %%
df
# Out:
#            SNo       Date              State      Country         Last Update  \
# 0            1 2020-01-22              Anhui        China 2020-01-22 17:00:00
# 1            2 2020-01-22            Beijing        China 2020-01-22 17:00:00
# 2            3 2020-01-22          Chongqing        China 2020-01-22 17:00:00
# 3            4 2020-01-22             Fujian        China 2020-01-22 17:00:00
# 4            5 2020-01-22              Gansu        China 2020-01-22 17:00:00
# ...        ...        ...                ...          ...                 ...
# 306424  306425 2021-05-29  Zaporizhia Oblast      Ukraine 2021-05-30 04:20:55
# 306425  306426 2021-05-29            Zeeland  Netherlands 2021-05-30 04:20:55
# 306426  306427 2021-05-29           Zhejiang        China 2021-05-30 04:20:55
# 306427  306428 2021-05-29    Zhytomyr Oblast      Ukraine 2021-05-30 04:20:55
# 306428  306429 2021-05-29       Zuid-Holland  Netherlands 2021-05-30 04:20:55
#
# ...

# %% [markdown]
# #### groupby

# %%
df = df.copy()
df1 = df.groupby('Date',as_index=False)['Confirmed','Deaths','Recovered','Day'].sum()
df
# Out:
# /var/folders/m2/297n8ms96hqg1h97r6lkg4lr0000gp/T/ipykernel_38846/3663882268.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 = df.groupby('Date',as_index=False)['Confirmed','Deaths','Recovered','Day'].sum()
#            SNo       Date              State      Country         Last Update  \
# 0            1 2020-01-22              Anhui        China 2020-01-22 17:00:00
# 1            2 2020-01-22            Beijing        China 2020-01-22 17:00:00
# 2            3 2020-01-22          Chongqing        China 2020-01-22 17:00:00
# 3            4 2020-01-22             Fujian        China 2020-01-22 17:00:00
# 4            5 2020-01-22              Gansu        China 2020-01-22 17:00:00
# ...        ...        ...                ...          ...                 ...
# 306424  306425 2021-05-29  Zaporizhia Oblast      Ukraine 2021-05-30 04:20:55
# ...

# %%
#Data  Visuvalization

# %%
plt.close("all")
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2019", periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
bar = pd.DataFrame(np.random.rand(10, 3), columns=["Confirmed", "Deaths", "Recovered"])
x = df['Date']
bar.plot.bar(width = 0.8)
# Out:
# <AxesSubplot:>

# %%
bar = pd.DataFrame(np.random.rand(10, 3), columns=["Confirmed", "Deaths", "Recovered"])
x = df['Country']
bar.plot.bar(width = 0.8)
# Out:
# <AxesSubplot:>

# %%
df1=df.groupby('Country')[['Confirmed','Deaths','Recovered']].mean().T.plot(kind='barh')
df1
# Out:
# <AxesSubplot:>

# %%
df = df.query("Country=='Hong Kong'")
df = df.groupby('Date',as_index=False)['Confirmed','Deaths','Recovered','Day'].sum()
df
# Out:
# /var/folders/m2/297n8ms96hqg1h97r6lkg4lr0000gp/T/ipykernel_38846/3747178278.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df = df.groupby('Date',as_index=False)['Confirmed','Deaths','Recovered','Day'].sum()
#           Date  Confirmed  Deaths  Recovered  Day
# 0   2020-01-22          0       0          0   22
# 1   2020-01-23          2       0          0   23
# 2   2020-01-24          2       0          0   24
# 3   2020-01-25          5       0          0   25
# 4   2020-01-26          8       0          0   26
# ..         ...        ...     ...        ...  ...
# 489 2021-05-25      11835     210      11560  145
# 490 2021-05-26      11836     210      11561  146
# 491 2021-05-27      11836     210      11561  147
# 492 2021-05-28      11836     210      11565  148
# 493 2021-05-29      11837     210      11571  149
#
# [494 rows x 5 columns]

# %%
df.plot(subplots=True, figsize=(10, 12))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
title = "Total cases"
df.groupby("Date").sum()["Recovered"].plot.bar(title=title).set_ylabel("Covid data")
# Out:
# Text(0, 0.5, 'Covid data')

# %%
sns.countplot(x = 'Country' , data = df)
plt.figure(figsize=(20,20))
plt.show()
